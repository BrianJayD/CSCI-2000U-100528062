# %%
#Attempted not finished
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from JSAnimation.IPython_display import display_animation

fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line

def animate(t):
    x = np.linspace(0, 2, 1000)
    y = np.sin(1.75 * np.pi * (x - 20 * t))
    line.set_data(x, y)
    return line

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)
display_animation(anim)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-8428a25fac66> in <module>()
#      20
#      21 anim = animation.FuncAnimation(fig, animate, init_func=init,
# ---> 22                                frames=200, interval=20, blit=True)
#      23 display_animation(anim)
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, **kwargs)
#    1132         self._save_seq = []
#    1133
# -> 1134         TimedAnimation.__init__(self, fig, **kwargs)
#    1135
#    1136         # Need to reset the saved seq, since right now it will contain data
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#     977
#     978         Animation.__init__(self, fig, event_source=event_source,
# --> 979                            *args, **kwargs)
#     980
#     981     def _step(self, *args):
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/animation.py in __init__(self, fig, event_source, blit)
#     606                                                       self._stop)
#     607         if self._blit:
# --> 608             self._setup_blit()
#     609
#     610     def _start(self, *args):
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/animation.py in _setup_blit(self)
#     875         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#     876                                                        self._handle_resize)
# --> 877         self._post_draw(None, self._blit)
#     878
#     879     def _handle_resize(self, *args):
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#     840             self._blit_draw(self._drawn_artists, self._blit_cache)
#     841         else:
# --> 842             self._fig.canvas.draw_idle()
#     843
#     844     # The rest of the code in this class is to facilitate easy blitting
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2024         if not self._is_idle_drawing:
#    2025             with self._idle_draw_cntx():
# -> 2026                 self.draw(*args, **kwargs)
#    2027
#    2028     def draw_cursor(self, event):
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1137
#    1138         self._cachedRenderer = renderer
# -> 1139         self.canvas.draw_event(renderer)
#    1140
#    1141     def draw_artist(self, a):
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1807         s = 'draw_event'
#    1808         event = DrawEvent(s, self, renderer)
# -> 1809         self.callbacks.process(s, event)
#    1810
#    1811     def resize_event(self):
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/cbook.py in process(self, s, *args, **kwargs)
#     560             for cid, proxy in list(six.iteritems(self.callbacks[s])):
#     561                 try:
# --> 562                     proxy(*args, **kwargs)
#     563                 except ReferenceError:
#     564                     self._remove_proxy(proxy)
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/cbook.py in __call__(self, *args, **kwargs)
#     427             mtd = self.func
#     428         # invoke the callable and return the result
# --> 429         return mtd(*args, **kwargs)
#     430
#     431     def __eq__(self, other):
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/animation.py in _start(self, *args)
#     618
#     619         # Now do any initial draw
# --> 620         self._init_draw()
#     621
#     622         # Add our callback for stepping the animation and
#
# /home/sliickz/anaconda3/lib/python3.5/site-packages/matplotlib/animation.py in _init_draw(self)
#    1162             self._draw_frame(next(self.new_frame_seq()))
#    1163         else:
# -> 1164             self._drawn_artists = self._init_func()
#    1165             if self._blit:
#    1166                 for a in self._drawn_artists:
#
# <ipython-input-5-8428a25fac66> in init()
#      10
#      11 def init():
# ---> 12     line.set_data([], [])
#      13     return line
#      14
#
# AttributeError: 'list' object has no attribute 'set_data'
